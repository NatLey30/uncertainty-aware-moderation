# %%
import torch
import json
import matplotlib.pyplot as plt
import numpy as np
import tqdm
from collections import defaultdict
import pandas as pd
import re
import random
from sklearn.metrics import f1_score, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from src.data import load_and_prepare_datasets
from src.utils import load_model
from src.gaussian_processes.prediction import predict_with_uncertainty
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
model, tokenizer = load_model("models/gp_finetuning/best", device=device)
model.eval()
# Out:
# [INFO] Loading model from: models/gp_finetuning/best
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_layer_norm.bias   | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# models/gp_finetuning/best\pytorch_model.bin
# [INFO] Model loaded successfully.
# DistilBERTWithGP(
#   (encoder): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): DistilBertSelfAttention(
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (projection): Linear(in_features=768, out_features=128, bias=True)
#   (gp_heads): ModuleList(
#     (0-5): 6 x GPBinaryClassifier(
#       (variational_strategy): VariationalStrategy(
#         (_variational_distribution): CholeskyVariationalDistribution()
#       )
#       (mean_module): ConstantMean()
#       (covar_module): ScaleKernel(
#         (base_kernel): RBFKernel(
#           (raw_lengthscale_constraint): Positive()
#         )
#         (raw_outputscale_constraint): Positive()
#       )
#     )
#   )
#   (likelihoods): ModuleList(
#     (0-5): 6 x BernoulliLikelihood(
#       (quadrature): GaussHermiteQuadrature1D()
#     )
#   )
# )

# %%
datasets, id2label = load_and_prepare_datasets(
    tokenizer=tokenizer,
)
 
test_set = datasets["test"]
print("Lenght of the test set:", len(test_set))
# Out:
# Jigsaw dataset already exists. Skipping download.
# Map:   0%|          | 0/129251 [00:00<?, ? examples/s]
# Map:   0%|          | 0/14362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/15958 [00:00<?, ? examples/s]
# Lenght of the test set: 15958

# %%
i = 4
sample = test_set[i]
 
text = tokenizer.decode(sample["input_ids"], skip_special_tokens=True)
label = sample["labels"]

print("======== EXAMPLE =========")
 
print("TEXT:", text)
print("TRUE LABELS:", label.numpy())
print("CLASS NAMES:", id2label)

print("\n MODEL PREDICTIONS:")

result = predict_with_uncertainty(model, tokenizer, text, id2label, device="cuda")
for label, prob, std in result["all_scores"]:
        print(f"{label:15s} | prob={prob:.4f} | std={std:.4f}")

print("=========================")
# Out:
# ======== EXAMPLE =========
# TEXT: fuck you wanker
# TRUE LABELS: [1. 1. 1. 0. 1. 0.]
# CLASS NAMES: ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
#
#  MODEL PREDICTIONS:
# toxic           | prob=0.9985 | std=0.0383
# severe_toxic    | prob=0.6181 | std=0.4858
# obscene         | prob=0.9990 | std=0.0321
# threat          | prob=0.0041 | std=0.0639
# insult          | prob=0.9618 | std=0.1918
# identity_hate   | prob=0.0681 | std=0.2519
# =========================

# %%
combos = defaultdict(list)

for i, sample in tqdm.tqdm(enumerate(test_set)):
    labels = tuple(int(x) for x in sample["labels"].numpy())
    text = tokenizer.decode(sample["input_ids"], skip_special_tokens=True)

    result = predict_with_uncertainty(
        model=model,
        tokenizer=tokenizer,
        text=text,
        id2label=id2label,
        device=device,
        threshold=0.5,
        top_k=3,
    )

    # probs y stds por label
    probs = np.array([p for _, p, _ in result["all_scores"]])
    stds  = np.array([s for _, _, s in result["all_scores"]])

    pred_labels = (probs >= 0.5).astype(int)
    correct = np.array_equal(np.array(labels), pred_labels)

    # métrica global de incertidumbre
    uncertainty = float(stds.mean())

    combos[labels].append({
        "index": i,
        "text": text,
        "combo_true": labels,
        "combo_pred": tuple(pred_labels.tolist()),
        "correct": correct,
        "uncertainty": uncertainty,
        "probs": probs.tolist(),
        "stds": stds.tolist(),
    })
# Out:
# 15958it [31:14,  8.51it/s]

# %%
all_samples = []
for combo_list in combos.values():
    all_samples.extend(combo_list)

uncertainties = np.array([x['uncertainty'] for x in all_samples])
corrects      = np.array([x['correct']     for x in all_samples]).astype(int)

num_labels = len(all_samples[0]['probs'])
y_true = np.array([x['combo_true'] for x in all_samples])
y_pred = np.array([x['combo_pred'] for x in all_samples])

print(f'Test samples: {len(all_samples):,}')
# Out:
# Test samples: 15,958

# %%
# Global exact-match accuracy
accuracy = corrects.mean()
print(f'Global exact-match accuracy: {accuracy:.4f}\n')

# Per-label accuracy and F1
label_cols = ['toxic','severe_toxic','obscene','threat','insult','identity_hate']
accs = [(y_true[:,i] == y_pred[:,i]).mean() for i in range(num_labels)]
f1s  = [f1_score(y_true[:,i], y_pred[:,i], zero_division=0) for i in range(num_labels)]
f1_micro = f1_score(y_true, y_pred, average='micro',  zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro',  zero_division=0)

print(f'  {"Label":15s} | {"Accuracy":>8s} | {"F1":>8s}')
print('  ' + '-'*38)
for lbl, acc, f1 in zip(label_cols, accs, f1s):
    print(f'  {lbl:15s} | {acc:>8.4f} | {f1:>8.4f}')
print('  ' + '-'*38)
print(f'  {"F1-micro":15s} | {" ":>8s} | {f1_micro:>8.4f}')
print(f'  {"F1-macro":15s} | {" ":>8s} | {f1_macro:>8.4f}')

# Bar chart
fig, ax = plt.subplots(figsize=(10, 4))
x = np.arange(num_labels)
ax.bar(x - 0.2, accs, 0.38, label='Accuracy', color='#3498db', alpha=0.85)
ax.bar(x + 0.2, f1s,  0.38, label='F1',       color='#e74c3c', alpha=0.85)
ax.axhline(f1_micro, linestyle='--', color='#e74c3c', linewidth=1, label=f'F1-micro={f1_micro:.3f}')
ax.axhline(f1_macro, linestyle=':',  color='#c0392b', linewidth=1, label=f'F1-macro={f1_macro:.3f}')
ax.set_xticks(x)
ax.set_xticklabels(label_cols, rotation=20, ha='right')
ax.set_ylim(0, 1.05)
ax.set_title('Per-label Accuracy and F1', fontweight='bold')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Global exact-match accuracy: 0.9246
#
#   Label           | Accuracy |       F1
#   --------------------------------------
#   toxic           |   0.9645 |   0.8153
#   severe_toxic    |   0.9911 |   0.4701
#   obscene         |   0.9825 |   0.8333
#   threat          |   0.9974 |   0.4384
#   insult          |   0.9775 |   0.7618
#   identity_hate   |   0.9932 |   0.5970
#   --------------------------------------
#   F1-micro        |          |   0.7819
#   F1-macro        |          |   0.6527

# %%
fig, axes = plt.subplots(2, 3, figsize=(13, 8))
axes = axes.flatten()

for i, (lbl, ax) in enumerate(zip(label_cols, axes)):
    cm = confusion_matrix(y_true[:, i], y_pred[:, i])
    im = ax.imshow(cm, cmap='Blues')
    for r in range(2):
        for c in range(2):
            ax.text(c, r, f'{cm[r,c]:,}', ha='center', va='center',
                    color='white' if cm[r,c] > cm.max()/2 else 'black', fontsize=11)
    ax.set_title(lbl, fontweight='bold')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_xticks([0,1]); ax.set_yticks([0,1])
    ax.set_xticklabels(['Neg','Pos']); ax.set_yticklabels(['Neg','Pos'])

plt.suptitle('Confusion Matrices per Label', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Sort by uncertainty
order      = np.argsort(uncertainties)
unc_sorted = uncertainties[order]
corr_sorted= corrects[order]

# Pearson correlation uncertainty ↔ error
errors = 1 - corrects
r = np.corrcoef(uncertainties, errors)[0, 1]
print(f'Pearson r (uncertainty ↔ error): {r:.3f}')

# Accuracy by decile
n_bins = 10
bins   = np.array_split(np.arange(len(unc_sorted)), n_bins)
bin_unc  = [unc_sorted[b].mean() for b in bins]
bin_acc  = [corr_sorted[b].mean() for b in bins]

print(f'\n  {"Bin":>4s} | {"Mean unc":>10s} | {"Accuracy":>10s}')
print('  ' + '-'*32)
for i,(u,a) in enumerate(zip(bin_unc, bin_acc)):
    print(f'  {i:>4d} | {u:>10.4f} | {a:>10.4f}')

# Top-k
k = int(0.2 * len(all_samples))
acc_high = corrects[np.argsort(uncertainties)[-k:]].mean()
acc_low  = corrects[np.argsort(uncertainties)[:k]].mean()
print(f'\nTop 20% most uncertain  → acc: {acc_high:.3f}')
print(f'Top 20% most confident  → acc: {acc_low:.3f}')

# Plot
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].plot(bin_unc, bin_acc, 'o-', color='#e74c3c', linewidth=2)
axes[0].set_xlabel('Mean uncertainty (std) per decile')
axes[0].set_ylabel('Accuracy')
axes[0].set_title(f'Accuracy vs. Uncertainty (r={r:.3f})', fontweight='bold')
axes[0].set_ylim(0, 1.05)
axes[0].grid(alpha=0.3)

axes[1].hist(uncertainties[corrects==1], bins=60, alpha=0.6, label='Correct',   color='#2ecc71', density=True)
axes[1].hist(uncertainties[corrects==0], bins=60, alpha=0.6, label='Incorrect', color='#e74c3c', density=True)
axes[1].set_xlabel('Uncertainty (mean GP std)')
axes[1].set_ylabel('Density')
axes[1].set_title('Uncertainty distribution: correct vs. incorrect', fontweight='bold')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Pearson r (uncertainty ↔ error): 0.660
#
#    Bin |   Mean unc |   Accuracy
#   --------------------------------
#      0 |     0.0048 |     0.9925
#      1 |     0.0050 |     0.9969
#      2 |     0.0052 |     0.9962
#      3 |     0.0053 |     0.9962
#      4 |     0.0054 |     0.9956
#      5 |     0.0056 |     0.9950
#      6 |     0.0058 |     0.9887
#      7 |     0.0064 |     0.9912
#      8 |     0.0311 |     0.8677
#      9 |     0.1843 |     0.4257
#
# Top 20% most uncertain  → acc: 0.647
# Top 20% most confident  → acc: 0.995

# %%
all_samples = []
for combo_list in combos.values():
    all_samples.extend(combo_list)

uncertainties = np.array([x["uncertainty"] for x in all_samples])
corrects = np.array([x["correct"] for x in all_samples]).astype(int)

# ordenar por incertidumbre
order = np.argsort(uncertainties)
unc_sorted = uncertainties[order]
corr_sorted = corrects[order]

# dividir en bins (ej: 10)
n_bins = 10
bins = np.array_split(np.arange(len(unc_sorted)), n_bins)

print("\nAccuracy por nivel de incertidumbre:")
for i, b in enumerate(bins):
    acc = corr_sorted[b].mean()
    unc_mean = unc_sorted[b].mean()
    print(f"Bin {i}: unc={unc_mean:.3f} | acc={acc:.3f}")
# Out:
# Accuracy por nivel de incertidumbre:
# Bin 0: unc=0.005 | acc=0.992
# Bin 1: unc=0.005 | acc=0.997
# Bin 2: unc=0.005 | acc=0.996
# Bin 3: unc=0.005 | acc=0.996
# Bin 4: unc=0.005 | acc=0.996
# Bin 5: unc=0.006 | acc=0.995
# Bin 6: unc=0.006 | acc=0.989
# Bin 7: unc=0.006 | acc=0.991
# Bin 8: unc=0.031 | acc=0.868
# Bin 9: unc=0.184 | acc=0.426

# %%
top2_uncertain_per_combo = {}

for combo, samples in combos.items():
    top2 = sorted(samples, key=lambda x: x["uncertainty"], reverse=True)[:2]
    top2_uncertain_per_combo[combo] = top2

serializable = {
    str(combo): samples
    for combo, samples in top2_uncertain_per_combo.items()
}

with open("top2_uncertain_per_combo_unfreezed.json", "w", encoding="utf-8") as f:
    json.dump(serializable, f, ensure_ascii=False, indent=2)

# %%
combo_stats = []
for combo, samples in combos.items():
    if not samples: continue
    combo_stats.append({
        'combo':   combo,
        'n':       len(samples),
        'acc':     np.mean([s['correct']     for s in samples]),
        'unc':     np.mean([s['uncertainty'] for s in samples]),
        'label':   ' + '.join(label_cols[i] for i,v in enumerate(combo) if v) or 'clean',
    })

combo_stats.sort(key=lambda x: -x['n'])
top_combos = combo_stats[:20]  # top-20 most frequent

labels_c = [f"{c['label']} (n={c['n']:,})" for c in top_combos]
accs_c   = [c['acc'] for c in top_combos]
uncs_c   = [c['unc'] for c in top_combos]

fig, axes = plt.subplots(1, 2, figsize=(15, 7))
colors_acc = ['#2ecc71' if a > 0.9 else '#f39c12' if a > 0.7 else '#e74c3c' for a in accs_c]
axes[0].barh(labels_c[::-1], accs_c[::-1], color=colors_acc[::-1], edgecolor='white')
axes[0].axvline(0.9, linestyle='--', color='gray', linewidth=0.8)
axes[0].set_xlabel('Accuracy')
axes[0].set_title('Accuracy per combo (top-20 by frequency)', fontweight='bold')
axes[0].set_xlim(0, 1.05)

axes[1].barh(labels_c[::-1], uncs_c[::-1], color='#3498db', edgecolor='white', alpha=0.8)
axes[1].set_xlabel('Mean uncertainty (GP std)')
axes[1].set_title('Mean uncertainty per combo', fontweight='bold')

plt.suptitle('Top-20 label combinations by frequency', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
def leet_speak(text):
    """Replace letters with visually similar digits (l33tspeak)."""
    return text.translate(str.maketrans('aeiost', '431057'))

def add_spaces(text):
    """Insert spaces between every character of long words."""
    return ' '.join(' '.join(w) if len(w) > 4 else w for w in text.split())

def unicode_homoglyphs(text):
    """Replace Latin letters with visually identical Cyrillic characters."""
    return text.translate(str.maketrans('aeoi', 'аеоі'))

def add_typos(text, rate=0.12, seed=42):
    """Randomly duplicate or drop characters."""
    rng, result = random.Random(seed), []
    for c in text:
        r = rng.random()
        if   r < rate/2:  pass
        elif r < rate:    result.extend([c, c])
        else:             result.append(c)
    return ''.join(result)

def punct_noise(text):
    """Intercalate dots between pairs of word characters."""
    return re.sub(r'(\w)(\w)', r'\1.\2', text)

def neutral_prefix(text):
    """Prepend an innocuous phrase to dilute toxicity signal."""
    return 'In my humble opinion, ' + text

TRANSFORMS = {
    'original':          lambda x: x,
    'leet_speak':        leet_speak,
    'add_spaces':        add_spaces,
    'unicode_homoglyphs':unicode_homoglyphs,
    'typos':             add_typos,
    'punct_noise':       punct_noise,
    'neutral_prefix':    neutral_prefix,
}
print('Perturbation functions:', list(TRANSFORMS.keys()))
# Out:
# Perturbation functions: ['original', 'leet_speak', 'add_spaces', 'unicode_homoglyphs', 'typos', 'punct_noise', 'neutral_prefix']

# %%
adv_corpus = []
for combo, samples in top2_uncertain_per_combo.items():
    for s in samples:
        adv_corpus.append({
            'text':        s['text'],
            'true_labels': s['combo_true'],
            'orig_preds':  s['combo_pred'],
            'orig_unc':    s['uncertainty'],
            'orig_correct':s['correct'],
            'combo':       combo,
            'combo_name':  ' + '.join(label_cols[i] for i,v in enumerate(combo) if v) or 'clean',
        })

print(f'Adversarial corpus: {len(adv_corpus)} samples')
print(f'  Covering {len(top2_uncertain_per_combo)} label combinations')
print(f'  Mean baseline uncertainty: {np.mean([s["orig_unc"] for s in adv_corpus]):.4f}')
print(f'  Baseline accuracy on these samples: {np.mean([s["orig_correct"] for s in adv_corpus]):.4f}')
# Out:
# Adversarial corpus: 51 samples
#   Covering 29 label combinations
#   Mean baseline uncertainty: 0.2730
#   Baseline accuracy on these samples: 0.1569

# %%
adv_results = []  # one entry per corpus sample

for entry in tqdm.tqdm(adv_corpus):
    row = {
        'combo':      entry['combo'],
        'combo_name': entry['combo_name'],
        'text':       entry['text'],
        'true_labels':entry['true_labels'],
        'orig_preds': entry['orig_preds'],
        'orig_unc':   entry['orig_unc'],
        'orig_correct':entry['orig_correct'],
        'variants':   [],
    }

    for t_name, t_fn in TRANSFORMS.items():
        if t_name == 'original':
            # We already have the original prediction — reuse it
            row['variants'].append({
                'transform':   'original',
                'text':        entry['text'],
                'preds':       list(entry['orig_preds']),
                'uncertainty': entry['orig_unc'],
                'flipped':     False,
                'correct':     entry['orig_correct'],
            })
            continue

        perturbed = t_fn(entry['text'])
        result    = predict_with_uncertainty(
            model=model, tokenizer=tokenizer, text=perturbed,
            id2label=id2label, device=device, threshold=0.5, top_k=3)

        probs = np.array([p for _,p,_ in result['all_scores']])
        stds  = np.array([s for _,_,s in result['all_scores']])
        preds = (probs >= 0.5).astype(int).tolist()
        unc   = float(stds.mean())

        row['variants'].append({
            'transform':   t_name,
            'text':        perturbed,
            'probs':       probs.tolist(),
            'stds':        stds.tolist(),
            'preds':       preds,
            'uncertainty': unc,
            'flipped':     preds != list(entry['orig_preds']),
            'correct':     bool(np.array_equal(preds, list(entry['true_labels']))),
            'unc_delta':   unc - entry['orig_unc'],  # +ve = more uncertain after perturbation
        })

    adv_results.append(row)

print(f'Done. {len(adv_results)} samples evaluated.')
# Out:
# 100%|██████████| 51/51 [00:43<00:00,  1.18it/s]
# Done. 51 samples evaluated.

# %%
transform_names = [t for t in TRANSFORMS.keys() if t != 'original']

summary = {}
for t_name in transform_names:
    flips, delta_uncs, accs = [], [], []
    for row in adv_results:
        v = next(x for x in row['variants'] if x['transform'] == t_name)
        flips.append(int(v['flipped']))
        delta_uncs.append(v['unc_delta'])
        accs.append(int(v['correct']))
    summary[t_name] = {
        'flip_rate': np.mean(flips),
        'mean_delta_unc': np.mean(delta_uncs),
        'accuracy': np.mean(accs),
    }

print(f'  {"Transform":25s} | {"Flip rate":>10s} | {"Mean Δunc":>10s} | {"Accuracy":>10s}')
print('  ' + '-'*64)
for t, s in summary.items():
    print(f'  {t:25s} | {s["flip_rate"]:>9.1%}  | {s["mean_delta_unc"]:>+10.4f} | {s["accuracy"]:>10.4f}')

# Bar chart
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
t_labels = list(summary.keys())
colors   = ['#e74c3c','#f39c12','#3498db','#9b59b6','#1abc9c','#e67e22']

axes[0].bar(t_labels, [summary[t]['flip_rate']      for t in t_labels], color=colors)
axes[0].set_title('Flip rate per perturbation', fontweight='bold')
axes[0].set_ylabel('Fraction of flipped predictions')
axes[0].set_ylim(0, 1)
axes[0].tick_params(axis='x', rotation=30)

axes[1].bar(t_labels, [summary[t]['mean_delta_unc'] for t in t_labels], color=colors)
axes[1].axhline(0, color='black', linewidth=0.8)
axes[1].set_title('Mean Δuncertainty (GP std)', fontweight='bold')
axes[1].set_ylabel('Δunc (positive = more uncertain after perturbation)')
axes[1].tick_params(axis='x', rotation=30)

axes[2].bar(t_labels, [summary[t]['accuracy']       for t in t_labels], color=colors)
axes[2].set_title('Accuracy after perturbation', fontweight='bold')
axes[2].set_ylabel('Fraction correct')
axes[2].set_ylim(0, 1)
axes[2].tick_params(axis='x', rotation=30)

plt.suptitle('Adversarial robustness — tested on top-2 uncertain samples per combo',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
#   Transform                 |  Flip rate |  Mean Δunc |   Accuracy
#   ----------------------------------------------------------------
#   leet_speak                |     96.1%  |    -0.1816 |     0.0588
#   add_spaces                |     76.5%  |    -0.0004 |     0.0588
#   unicode_homoglyphs        |     90.2%  |    -0.1855 |     0.0784
#   typos                     |     76.5%  |    -0.0655 |     0.1176
#   punct_noise               |     86.3%  |    -0.0742 |     0.0588
#   neutral_prefix            |     39.2%  |    -0.0177 |     0.1176

# %%
delta_flipped   = []
delta_stable    = []

for row in adv_results:
    for v in row['variants']:
        if v['transform'] == 'original': continue
        if v['flipped']:  delta_flipped.append(v['unc_delta'])
        else:             delta_stable.append(v['unc_delta'])

print(f'Flipped predictions  — mean Δunc: {np.mean(delta_flipped):+.4f}  (n={len(delta_flipped)})')
print(f'Stable  predictions  — mean Δunc: {np.mean(delta_stable):+.4f}  (n={len(delta_stable)})')

from scipy import stats
t_stat, p_val = stats.ttest_ind(delta_flipped, delta_stable)
print(f'\nWelch t-test: t={t_stat:.3f}, p={p_val:.4f}')
print('→ GP uncertainty is a statistically significant predictor of prediction flips.' if p_val < 0.05
      else '→ No statistically significant difference detected.')

fig, ax = plt.subplots(figsize=(9, 4))
ax.hist(delta_flipped, bins=40, alpha=0.65, label='Flipped', color='#e74c3c', density=True)
ax.hist(delta_stable,  bins=40, alpha=0.65, label='Stable',  color='#2ecc71', density=True)
ax.axvline(np.mean(delta_flipped), color='#c0392b', linestyle='--', linewidth=1.5, label=f'Mean flipped {np.mean(delta_flipped):+.3f}')
ax.axvline(np.mean(delta_stable),  color='#27ae60', linestyle='--', linewidth=1.5, label=f'Mean stable  {np.mean(delta_stable):+.3f}')
ax.axvline(0, color='black', linewidth=0.8)
ax.set_xlabel('Δuncertainty (perturbed − original)')
ax.set_ylabel('Density')
ax.set_title('Uncertainty change: flipped vs. stable predictions', fontweight='bold')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# Flipped predictions  — mean Δunc: -0.1081  (n=237)
# Stable  predictions  — mean Δunc: -0.0168  (n=69)
#
# Welch t-test: t=-6.678, p=0.0000
# → GP uncertainty is a statistically significant predictor of prediction flips.

# %%
for t_name in transform_names:
    flipped_cases = [
        row for row in adv_results
        if next(x for x in row['variants'] if x['transform']==t_name)['flipped']
    ]
    if not flipped_cases:
        print(f'\n[{t_name}] No flips.')
        continue
    print(f'\n' + '='*60)
    print(f'Transform: {t_name}  ({len(flipped_cases)} flips / {len(adv_results)} samples)')
    print('='*60)
    for row in flipped_cases:
        v = next(x for x in row['variants'] if x['transform']==t_name)
        print(f'\n  Combo      : {row["combo"]}  [{row["combo_name"]}]')
        print(f'  True labels: {list(row["true_labels"])}')
        print(f'  Orig pred  : {list(row["orig_preds"])}  (correct={row["orig_correct"]})')
        print(f'  New  pred  : {v["preds"]}')
        print(f'  Orig unc   : {row["orig_unc"]:.4f}  →  New unc: {v["uncertainty"]:.4f}  (Δ={v["unc_delta"]:+.4f})')
        print(f'  Original   : {row["text"][:100]}')
        print(f'  Perturbed  : {v["text"][:100]}')
# Out:
# ============================================================
# Transform: leet_speak  (49 flips / 51 samples)
# ============================================================
#
#   Combo      : (0, 0, 0, 0, 0, 0)  [clean]
#   True labels: [0, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3387  →  New unc: 0.0906  (Δ=-0.2481)
#   Original   : indeed, he is not surprised that that your fascist state was repeatedly elected nekolirkta as the bi
#   Perturbed  : 1nd33d, h3 15 n07 5urpr153d 7h47 7h47 y0ur f45c157 57473 w45 r3p3473dly 3l3c73d n3k0l1rk74 45 7h3 b1
#
#   Combo      : (0, 0, 0, 0, 0, 0)  [clean]
#   True labels: [0, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2677  →  New unc: 0.0072  (Δ=-0.2606)
#   Original   : , 1 june 2007 ( utc ) travis accepted long ago, being a diaper - fetishizing queer, that censorship
#   Perturbed  : , 1 jun3 2007 ( u7c ) 7r4v15 4cc3p73d l0ng 4g0, b31ng 4 d14p3r - f3715h1z1ng qu33r, 7h47 c3n50r5h1p
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3008  →  New unc: 0.1030  (Δ=-0.1978)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : h3y h3y f4gg07, 4r3 y0u d34d y37? 0r 4r3 y0u w47ch1ng y0ur m0m g3771ng r4p3d by f1l7hy p1g5? wh1ch 0
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3008  →  New unc: 0.1030  (Δ=-0.1978)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : h3y h3y f4gg07, 4r3 y0u d34d y37? 0r 4r3 y0u w47ch1ng y0ur m0m g3771ng r4p3d by f1l7hy p1g5? wh1ch 0
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2956  →  New unc: 0.0184  (Δ=-0.2772)
#   Original   : " vandalism thanks for lookin ' out for me. naw, i ' m not going to bother saving it. it ' s not cre
#   Perturbed  : " v4nd4l15m 7h4nk5 f0r l00k1n ' 0u7 f0r m3. n4w, 1 ' m n07 g01ng 70 b07h3r 54v1ng 17. 17 ' 5 n07 cr3
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2841  →  New unc: 0.0254  (Δ=-0.2587)
#   Original   : you do not deserve to be alive drop dead now
#   Perturbed  : y0u d0 n07 d353rv3 70 b3 4l1v3 dr0p d34d n0w
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3402  →  New unc: 0.0767  (Δ=-0.2635)
#   Original   : i think that you are so sexy and hot and sexy that i would just have sex with you and make out with
#   Perturbed  : 1 7h1nk 7h47 y0u 4r3 50 53xy 4nd h07 4nd 53xy 7h47 1 w0uld ju57 h4v3 53x w17h y0u 4nd m4k3 0u7 w17h
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2880  →  New unc: 0.1058  (Δ=-0.1823)
#   Original   : trout?? listen up boy this is not the kind of abuse i like to get from you on this damn ncyclopedia
#   Perturbed  : 7r0u7?? l1573n up b0y 7h15 15 n07 7h3 k1nd 0f 4bu53 1 l1k3 70 g37 fr0m y0u 0n 7h15 d4mn ncycl0p3d14
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3107  →  New unc: 0.1984  (Δ=-0.1123)
#   Original   : anyone else glad that this stupid fucker offed himself? i sure am. hey britbarb, fuck off. your neph
#   Perturbed  : 4ny0n3 3l53 gl4d 7h47 7h15 57up1d fuck3r 0ff3d h1m53lf? 1 5ur3 4m. h3y br17b4rb, fuck 0ff. y0ur n3ph
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3100  →  New unc: 0.0201  (Δ=-0.2900)
#   Original   : shut up, idiot! it is true! now, go away and die!
#   Perturbed  : 5hu7 up, 1d107! 17 15 7ru3! n0w, g0 4w4y 4nd d13!
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 1, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3017  →  New unc: 0.1026  (Δ=-0.1991)
#   Original   : they will die and none of them will block me again! hell hell hell hell hell crap!
#   Perturbed  : 7h3y w1ll d13 4nd n0n3 0f 7h3m w1ll bl0ck m3 4g41n! h3ll h3ll h3ll h3ll h3ll cr4p!
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2747  →  New unc: 0.0143  (Δ=-0.2604)
#   Original   : nigga owe me some money young buck and plies are on that song http : / / limelinx. com / files / 1ee
#   Perturbed  : n1gg4 0w3 m3 50m3 m0n3y y0ung buck 4nd pl135 4r3 0n 7h47 50ng h77p : / / l1m3l1nx. c0m / f1l35 / 133
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2842  →  New unc: 0.1023  (Δ=-0.1818)
#   Original   : are you gay? are you a nigger? are you a gay nigger? then the gay nigger association of america is r
#   Perturbed  : 4r3 y0u g4y? 4r3 y0u 4 n1gg3r? 4r3 y0u 4 g4y n1gg3r? 7h3n 7h3 g4y n1gg3r 4550c14710n 0f 4m3r1c4 15 r
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2667  →  New unc: 0.2113  (Δ=-0.0555)
#   Original   : fuck off, nigger you ' d look real good hanging from a tree
#   Perturbed  : fuck 0ff, n1gg3r y0u ' d l00k r34l g00d h4ng1ng fr0m 4 7r33
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3437  →  New unc: 0.0051  (Δ=-0.3386)
#   Original   : kill all niggers. i have hard, that others have said this.. should this be included? that racists so
#   Perturbed  : k1ll 4ll n1gg3r5. 1 h4v3 h4rd, 7h47 07h3r5 h4v3 541d 7h15.. 5h0uld 7h15 b3 1nclud3d? 7h47 r4c1575 50
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3064  →  New unc: 0.0531  (Δ=-0.2533)
#   Original   : " ok, let me say it again come on, now you guys are just being piece of shit jews. i mean you have t
#   Perturbed  : " 0k, l37 m3 54y 17 4g41n c0m3 0n, n0w y0u guy5 4r3 ju57 b31ng p13c3 0f 5h17 j3w5. 1 m34n y0u h4v3 7
#
#   Combo      : (1, 1, 1, 0, 0, 0)  [toxic + severe_toxic + obscene]
#   True labels: [1, 1, 1, 0, 0, 0]
#   Orig pred  : [1, 1, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2757  →  New unc: 0.0051  (Δ=-0.2707)
#   Original   : stupid assholes never die rightß instead ; they become wackpedia admins : die
#   Perturbed  : 57up1d 455h0l35 n3v3r d13 r1gh7ß 1n5734d ; 7h3y b3c0m3 w4ckp3d14 4dm1n5 : d13
#
#   Combo      : (0, 0, 1, 0, 0, 0)  [obscene]
#   True labels: [0, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2758  →  New unc: 0.0915  (Δ=-0.1843)
#   Original   : the only nonsense i will approve is nonsense committed by 1 ) chaka zulu warriors. 2 ) anglican gay
#   Perturbed  : 7h3 0nly n0n53n53 1 w1ll 4ppr0v3 15 n0n53n53 c0mm1773d by 1 ) ch4k4 zulu w4rr10r5. 2 ) 4ngl1c4n g4y
#
#   Combo      : (0, 0, 1, 0, 0, 0)  [obscene]
#   True labels: [0, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2611  →  New unc: 0.0067  (Δ=-0.2544)
#   Original   : nigger hatin me this is not a johnnie rebel song, but a david allen coe song.
#   Perturbed  : n1gg3r h471n m3 7h15 15 n07 4 j0hnn13 r3b3l 50ng, bu7 4 d4v1d 4ll3n c03 50ng.
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2412  →  New unc: 0.0054  (Δ=-0.2358)
#   Original   : nazi sean hoyland vandalized these pages.
#   Perturbed  : n4z1 534n h0yl4nd v4nd4l1z3d 7h353 p4g35.
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2350  →  New unc: 0.0540  (Δ=-0.1810)
#   Original   : hit 3 times for the same crime so i get 2 warnings and a block for the second time i called out a va
#   Perturbed  : h17 3 71m35 f0r 7h3 54m3 cr1m3 50 1 g37 2 w4rn1ng5 4nd 4 bl0ck f0r 7h3 53c0nd 71m3 1 c4ll3d 0u7 4 v4
#
#   Combo      : (1, 0, 0, 0, 0, 1)  [toxic + identity_hate]
#   True labels: [1, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3724  →  New unc: 0.0056  (Δ=-0.3668)
#   Original   : he worshipped satan and sacrificed babies in his name. muslims are terrorists and should be shot. al
#   Perturbed  : h3 w0r5h1pp3d 5474n 4nd 54cr1f1c3d b4b135 1n h15 n4m3. mu5l1m5 4r3 73rr0r1575 4nd 5h0uld b3 5h07. 4l
#
#   Combo      : (1, 0, 0, 0, 0, 1)  [toxic + identity_hate]
#   True labels: [1, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2611  →  New unc: 0.1345  (Δ=-0.1266)
#   Original   : whats up gook whats up you asian gook chink man hoe chow how much rice did you pick today? all asian
#   Perturbed  : wh475 up g00k wh475 up y0u 4514n g00k ch1nk m4n h03 ch0w h0w much r1c3 d1d y0u p1ck 70d4y? 4ll 4514n
#
#   Combo      : (1, 0, 1, 1, 1, 1)  [toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 0, 1, 1, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2713  →  New unc: 0.1546  (Δ=-0.1168)
#   Original   : my mate told me you were a fuckin homosexual. you are dead.
#   Perturbed  : my m473 70ld m3 y0u w3r3 4 fuck1n h0m053xu4l. y0u 4r3 d34d.
#
#   Combo      : (1, 0, 1, 1, 1, 1)  [toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 0, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2576  →  New unc: 0.2353  (Δ=-0.0223)
#   Original   : bitch you are a fucking hore. you suck dick you big ass hole. you are gay you faggot ass bitch. you
#   Perturbed  : b17ch y0u 4r3 4 fuck1ng h0r3. y0u 5uck d1ck y0u b1g 455 h0l3. y0u 4r3 g4y y0u f4gg07 455 b17ch. y0u
#
#   Combo      : (1, 1, 1, 1, 1, 1)  [toxic + severe_toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 1, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3258  →  New unc: 0.2364  (Δ=-0.0894)
#   Original   : anyone who supports this is fucking sick. men and underaged fucking kids????????????????????????????
#   Perturbed  : 4ny0n3 wh0 5upp0r75 7h15 15 fuck1ng 51ck. m3n 4nd und3r4g3d fuck1ng k1d5????????????????????????????
#
#   Combo      : (1, 1, 1, 1, 1, 1)  [toxic + severe_toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 1, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2288  →  New unc: 0.2331  (Δ=+0.0044)
#   Original   : faggot you lil piece of shit i haven ’ t vandalised nothing i will fuck u up wh
#   Perturbed  : f4gg07 y0u l1l p13c3 0f 5h17 1 h4v3n ’ 7 v4nd4l153d n07h1ng 1 w1ll fuck u up wh
#
#   Combo      : (1, 0, 1, 1, 1, 0)  [toxic + obscene + threat + insult]
#   True labels: [1, 0, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=True)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3096  →  New unc: 0.0926  (Δ=-0.2171)
#   Original   : i will murder your pets and slash your tires. you are such a giant assclown. my name is byran mattis
#   Perturbed  : 1 w1ll murd3r y0ur p375 4nd 5l45h y0ur 71r35. y0u 4r3 5uch 4 g14n7 455cl0wn. my n4m3 15 byr4n m47715
#
#   Combo      : (1, 0, 1, 1, 1, 0)  [toxic + obscene + threat + insult]
#   True labels: [1, 0, 1, 1, 1, 0]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3073  →  New unc: 0.1679  (Δ=-0.1394)
#   Original   : if you block this account i will rape your children piss off you fucking admin.
#   Perturbed  : 1f y0u bl0ck 7h15 4cc0un7 1 w1ll r4p3 y0ur ch1ldr3n p155 0ff y0u fuck1ng 4dm1n.
#
#   Combo      : (1, 0, 0, 1, 0, 0)  [toxic + threat]
#   True labels: [1, 0, 0, 1, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=True)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2648  →  New unc: 0.0994  (Δ=-0.1654)
#   Original   : bban be and u die. understand? efore
#   Perturbed  : bb4n b3 4nd u d13. und3r574nd? 3f0r3
#
#   Combo      : (1, 0, 0, 1, 0, 0)  [toxic + threat]
#   True labels: [1, 0, 0, 1, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2607  →  New unc: 0.1016  (Δ=-0.1591)
#   Original   : evula you may have blocked my friends but you wont block me or you will be sorry. you are doomed evu
#   Perturbed  : 3vul4 y0u m4y h4v3 bl0ck3d my fr13nd5 bu7 y0u w0n7 bl0ck m3 0r y0u w1ll b3 50rry. y0u 4r3 d00m3d 3vu
#
#   Combo      : (1, 0, 0, 1, 1, 0)  [toxic + threat + insult]
#   True labels: [1, 0, 0, 1, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.1499  →  New unc: 0.0105  (Δ=-0.1394)
#   Original   : insult me once more and i swear you go down. understand little coward?
#   Perturbed  : 1n5ul7 m3 0nc3 m0r3 4nd 1 5w34r y0u g0 d0wn. und3r574nd l177l3 c0w4rd?
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3212  →  New unc: 0.0052  (Δ=-0.3160)
#   Original   : you should die from cancer.
#   Perturbed  : y0u 5h0uld d13 fr0m c4nc3r.
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3102  →  New unc: 0.0872  (Δ=-0.2230)
#   Original   : i am going to shoot you in the head and laugh as your brains splatter onto the ground. i am going to
#   Perturbed  : 1 4m g01ng 70 5h007 y0u 1n 7h3 h34d 4nd l4ugh 45 y0ur br41n5 5pl4773r 0n70 7h3 gr0und. 1 4m g01ng 70
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2734  →  New unc: 0.1612  (Δ=-0.1122)
#   Original   : shutup [ [ who u think u is you gay nobody thats why you got that userbox your orientation doesn ' t
#   Perturbed  : 5hu7up [ [ wh0 u 7h1nk u 15 y0u g4y n0b0dy 7h475 why y0u g07 7h47 u53rb0x y0ur 0r13n74710n d035n ' 7
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2507  →  New unc: 0.1038  (Δ=-0.1469)
#   Original   : to subject objective criteria such as references to subjective quasi - criteria such as google count
#   Perturbed  : 70 5ubj3c7 0bj3c71v3 cr173r14 5uch 45 r3f3r3nc35 70 5ubj3c71v3 qu451 - cr173r14 5uch 45 g00gl3 c0un7
#
#   Combo      : (1, 1, 0, 1, 1, 0)  [toxic + severe_toxic + threat + insult]
#   True labels: [1, 1, 0, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3340  →  New unc: 0.1028  (Δ=-0.2312)
#   Original   : im going to kill you all!!!!!!!!!!!!!!!!! i ' m serious, you are all mean nasty idiots who deserve t
#   Perturbed  : 1m g01ng 70 k1ll y0u 4ll!!!!!!!!!!!!!!!!! 1 ' m 53r10u5, y0u 4r3 4ll m34n n457y 1d1075 wh0 d353rv3 7
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2741  →  New unc: 0.1044  (Δ=-0.1697)
#   Original   : it is obvius to, me, a black man, that orange is for da black gs, blue is for mexicans and yellow is
#   Perturbed  : 17 15 0bv1u5 70, m3, 4 bl4ck m4n, 7h47 0r4ng3 15 f0r d4 bl4ck g5, blu3 15 f0r m3x1c4n5 4nd y3ll0w 15
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2187  →  New unc: 0.0050  (Δ=-0.2137)
#   Original   : why is your wiener so small? it is because you are asian?
#   Perturbed  : why 15 y0ur w13n3r 50 5m4ll? 17 15 b3c4u53 y0u 4r3 4514n?
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2562  →  New unc: 0.1069  (Δ=-0.1493)
#   Original   : i thought you were gonna block me? homo.
#   Perturbed  : 1 7h0ugh7 y0u w3r3 g0nn4 bl0ck m3? h0m0.
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2278  →  New unc: 0.1027  (Δ=-0.1251)
#   Original   : " something needs to be added about this!! what a friggin hypocrite!! leaving her husband and 3 youn
#   Perturbed  : " 50m37h1ng n33d5 70 b3 4dd3d 4b0u7 7h15!! wh47 4 fr1gg1n hyp0cr173!! l34v1ng h3r hu5b4nd 4nd 3 y0un
#
#   Combo      : (1, 0, 0, 0, 1, 1)  [toxic + insult + identity_hate]
#   True labels: [1, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2842  →  New unc: 0.1123  (Δ=-0.1720)
#   Original   : ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay
#   Perturbed  : ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y ur g4y
#
#   Combo      : (1, 0, 0, 0, 1, 1)  [toxic + insult + identity_hate]
#   True labels: [1, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=True)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2714  →  New unc: 0.0731  (Δ=-0.1982)
#   Original   : you are very gay you ' re gay
#   Perturbed  : y0u 4r3 v3ry g4y y0u ' r3 g4y
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=True)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3236  →  New unc: 0.1537  (Δ=-0.1699)
#   Original   : dust filter, if you rvv it again! i will fuckin kill you! i will block you, i will blank your talk p
#   Perturbed  : du57 f1l73r, 1f y0u rvv 17 4g41n! 1 w1ll fuck1n k1ll y0u! 1 w1ll bl0ck y0u, 1 w1ll bl4nk y0ur 74lk p
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3113  →  New unc: 0.1030  (Δ=-0.2083)
#   Original   : i want you i wanna rape you good. i want your sexy body and sexually abuse you!
#   Perturbed  : 1 w4n7 y0u 1 w4nn4 r4p3 y0u g00d. 1 w4n7 y0ur 53xy b0dy 4nd 53xu4lly 4bu53 y0u!
#
#   Combo      : (0, 0, 1, 0, 1, 1)  [obscene + insult + identity_hate]
#   True labels: [0, 0, 1, 0, 1, 1]
#   Orig pred  : [0, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.1104  →  New unc: 0.1092  (Δ=-0.0013)
#   Original   : people who are athiests will go to he double hockey stick. have fun there with the d e m o n s. you
#   Perturbed  : p30pl3 wh0 4r3 47h13575 w1ll g0 70 h3 d0ubl3 h0ck3y 571ck. h4v3 fun 7h3r3 w17h 7h3 d 3 m 0 n 5. y0u
#
#   Combo      : (1, 0, 1, 0, 0, 1)  [toxic + obscene + identity_hate]
#   True labels: [1, 0, 1, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2286  →  New unc: 0.1071  (Δ=-0.1215)
#   Original   : wtf are you stupid white idiots talking about now i no that ur white becoz in my experience only whi
#   Perturbed  : w7f 4r3 y0u 57up1d wh173 1d1075 74lk1ng 4b0u7 n0w 1 n0 7h47 ur wh173 b3c0z 1n my 3xp3r13nc3 0nly wh1
#
#   Combo      : (1, 1, 0, 0, 1, 0)  [toxic + severe_toxic + insult]
#   True labels: [1, 1, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2745  →  New unc: 0.1030  (Δ=-0.1715)
#   Original   : you should all rue the day you were born!!!! i have taken over this page!!!! i am the god of chocobo
#   Perturbed  : y0u 5h0uld 4ll ru3 7h3 d4y y0u w3r3 b0rn!!!! 1 h4v3 74k3n 0v3r 7h15 p4g3!!!! 1 4m 7h3 g0d 0f ch0c0b0
#
#   Combo      : (1, 0, 0, 1, 1, 1)  [toxic + threat + insult + identity_hate]
#   True labels: [1, 0, 0, 1, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2533  →  New unc: 0.0063  (Δ=-0.2470)
#   Original   : " " " i think we should kill all the jews and homosexuals and handicaped people. " ", ( said adolf h
#   Perturbed  : " " " 1 7h1nk w3 5h0uld k1ll 4ll 7h3 j3w5 4nd h0m053xu4l5 4nd h4nd1c4p3d p30pl3. " ", ( 541d 4d0lf h
#
# ============================================================
# Transform: add_spaces  (39 flips / 51 samples)
# ============================================================
#
#   Combo      : (0, 0, 0, 0, 0, 0)  [clean]
#   True labels: [0, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3387  →  New unc: 0.2764  (Δ=-0.0623)
#   Original   : indeed, he is not surprised that that your fascist state was repeatedly elected nekolirkta as the bi
#   Perturbed  : i n d e e d , he is not s u r p r i s e d that that your f a s c i s t s t a t e was r e p e a t e d
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.3008  →  New unc: 0.3149  (Δ=+0.0141)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : hey hey f a g g o t , are you dead yet? or are you w a t c h i n g your mom g e t t i n g r a p e d
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.3008  →  New unc: 0.3149  (Δ=+0.0141)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : hey hey f a g g o t , are you dead yet? or are you w a t c h i n g your mom g e t t i n g r a p e d
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2956  →  New unc: 0.2665  (Δ=-0.0291)
#   Original   : " vandalism thanks for lookin ' out for me. naw, i ' m not going to bother saving it. it ' s not cre
#   Perturbed  : " v a n d a l i s m t h a n k s for l o o k i n ' out for me. naw, i ' m not g o i n g to b o t h e
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2841  →  New unc: 0.3076  (Δ=+0.0235)
#   Original   : you do not deserve to be alive drop dead now
#   Perturbed  : you do not d e s e r v e to be a l i v e drop dead now
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3402  →  New unc: 0.2725  (Δ=-0.0678)
#   Original   : i think that you are so sexy and hot and sexy that i would just have sex with you and make out with
#   Perturbed  : i t h i n k that you are so sexy and hot and sexy that i w o u l d just have sex with you and make o
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2880  →  New unc: 0.2265  (Δ=-0.0615)
#   Original   : trout?? listen up boy this is not the kind of abuse i like to get from you on this damn ncyclopedia
#   Perturbed  : t r o u t ? ? l i s t e n up boy this is not the kind of a b u s e i like to get from you on this da
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.3107  →  New unc: 0.2301  (Δ=-0.0805)
#   Original   : anyone else glad that this stupid fucker offed himself? i sure am. hey britbarb, fuck off. your neph
#   Perturbed  : a n y o n e else glad that this s t u p i d f u c k e r o f f e d h i m s e l f ? i sure am. hey b r
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 1, 0, 0]
#   Orig unc   : 0.3100  →  New unc: 0.3070  (Δ=-0.0030)
#   Original   : shut up, idiot! it is true! now, go away and die!
#   Perturbed  : shut up, i d i o t ! it is t r u e ! now, go away and die!
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2747  →  New unc: 0.2490  (Δ=-0.0257)
#   Original   : nigga owe me some money young buck and plies are on that song http : / / limelinx. com / files / 1ee
#   Perturbed  : n i g g a owe me some m o n e y y o u n g buck and p l i e s are on that song http : / / l i m e l i
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2667  →  New unc: 0.2176  (Δ=-0.0491)
#   Original   : fuck off, nigger you ' d look real good hanging from a tree
#   Perturbed  : fuck off, n i g g e r you ' d look real good h a n g i n g from a tree
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.3437  →  New unc: 0.3636  (Δ=+0.0199)
#   Original   : kill all niggers. i have hard, that others have said this.. should this be included? that racists so
#   Perturbed  : kill all n i g g e r s . i have h a r d , that o t h e r s have said t h i s . . s h o u l d this be
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.3064  →  New unc: 0.2325  (Δ=-0.0739)
#   Original   : " ok, let me say it again come on, now you guys are just being piece of shit jews. i mean you have t
#   Perturbed  : " ok, let me say it a g a i n come on, now you guys are just b e i n g p i e c e of shit j e w s . i
#
#   Combo      : (0, 0, 1, 0, 0, 0)  [obscene]
#   True labels: [0, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2758  →  New unc: 0.2238  (Δ=-0.0519)
#   Original   : the only nonsense i will approve is nonsense committed by 1 ) chaka zulu warriors. 2 ) anglican gay
#   Perturbed  : the only n o n s e n s e i will a p p r o v e is n o n s e n s e c o m m i t t e d by 1 ) c h a k a
#
#   Combo      : (0, 0, 1, 0, 0, 0)  [obscene]
#   True labels: [0, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 1]
#   Orig unc   : 0.2611  →  New unc: 0.3187  (Δ=+0.0576)
#   Original   : nigger hatin me this is not a johnnie rebel song, but a david allen coe song.
#   Perturbed  : n i g g e r h a t i n me this is not a j o h n n i e r e b e l s o n g , but a d a v i d a l l e n c
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2412  →  New unc: 0.2292  (Δ=-0.0120)
#   Original   : nazi sean hoyland vandalized these pages.
#   Perturbed  : nazi sean h o y l a n d v a n d a l i z e d t h e s e p a g e s .
#
#   Combo      : (1, 0, 0, 0, 0, 1)  [toxic + identity_hate]
#   True labels: [1, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3724  →  New unc: 0.2852  (Δ=-0.0872)
#   Original   : he worshipped satan and sacrificed babies in his name. muslims are terrorists and should be shot. al
#   Perturbed  : he w o r s h i p p e d s a t a n and s a c r i f i c e d b a b i e s in his n a m e . m u s l i m s
#
#   Combo      : (1, 0, 0, 0, 0, 1)  [toxic + identity_hate]
#   True labels: [1, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2611  →  New unc: 0.2730  (Δ=+0.0119)
#   Original   : whats up gook whats up you asian gook chink man hoe chow how much rice did you pick today? all asian
#   Perturbed  : w h a t s up gook w h a t s up you a s i a n gook c h i n k man hoe chow how much rice did you pick
#
#   Combo      : (1, 0, 1, 1, 1, 1)  [toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 0, 1, 1, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2713  →  New unc: 0.1942  (Δ=-0.0771)
#   Original   : my mate told me you were a fuckin homosexual. you are dead.
#   Perturbed  : my mate told me you were a f u c k i n h o m o s e x u a l . you are d e a d .
#
#   Combo      : (1, 1, 1, 1, 1, 1)  [toxic + severe_toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 1, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.3258  →  New unc: 0.2551  (Δ=-0.0707)
#   Original   : anyone who supports this is fucking sick. men and underaged fucking kids????????????????????????????
#   Perturbed  : a n y o n e who s u p p o r t s this is f u c k i n g s i c k . men and u n d e r a g e d f u c k i
#
#   Combo      : (1, 1, 1, 1, 1, 1)  [toxic + severe_toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 1, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2288  →  New unc: 0.2494  (Δ=+0.0206)
#   Original   : faggot you lil piece of shit i haven ’ t vandalised nothing i will fuck u up wh
#   Perturbed  : f a g g o t you lil p i e c e of shit i h a v e n ’ t v a n d a l i s e d n o t h i n g i will fuck
#
#   Combo      : (1, 0, 1, 1, 1, 0)  [toxic + obscene + threat + insult]
#   True labels: [1, 0, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=True)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3096  →  New unc: 0.2457  (Δ=-0.0639)
#   Original   : i will murder your pets and slash your tires. you are such a giant assclown. my name is byran mattis
#   Perturbed  : i will m u r d e r your pets and s l a s h your t i r e s . you are such a g i a n t a s s c l o w n
#
#   Combo      : (1, 0, 0, 1, 0, 0)  [toxic + threat]
#   True labels: [1, 0, 0, 1, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=True)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.2648  →  New unc: 0.3201  (Δ=+0.0553)
#   Original   : bban be and u die. understand? efore
#   Perturbed  : bban be and u die. u n d e r s t a n d ? e f o r e
#
#   Combo      : (1, 0, 0, 1, 0, 0)  [toxic + threat]
#   True labels: [1, 0, 0, 1, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=True)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.2607  →  New unc: 0.3160  (Δ=+0.0553)
#   Original   : evula you may have blocked my friends but you wont block me or you will be sorry. you are doomed evu
#   Perturbed  : e v u l a you may have b l o c k e d my f r i e n d s but you wont b l o c k me or you will be s o r
#
#   Combo      : (1, 0, 0, 1, 1, 0)  [toxic + threat + insult]
#   True labels: [1, 0, 0, 1, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.1499  →  New unc: 0.2639  (Δ=+0.1139)
#   Original   : insult me once more and i swear you go down. understand little coward?
#   Perturbed  : i n s u l t me once more and i s w e a r you go d o w n . u n d e r s t a n d l i t t l e c o w a r
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 1, 1, 0]
#   Orig unc   : 0.3212  →  New unc: 0.2982  (Δ=-0.0230)
#   Original   : you should die from cancer.
#   Perturbed  : you s h o u l d die from c a n c e r .
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3102  →  New unc: 0.2462  (Δ=-0.0640)
#   Original   : i am going to shoot you in the head and laugh as your brains splatter onto the ground. i am going to
#   Perturbed  : i am g o i n g to s h o o t you in the head and l a u g h as your b r a i n s s p l a t t e r onto t
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 1]
#   Orig unc   : 0.2734  →  New unc: 0.2342  (Δ=-0.0392)
#   Original   : shutup [ [ who u think u is you gay nobody thats why you got that userbox your orientation doesn ' t
#   Perturbed  : s h u t u p [ [ who u t h i n k u is you gay n o b o d y t h a t s why you got that u s e r b o x yo
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2507  →  New unc: 0.3009  (Δ=+0.0502)
#   Original   : to subject objective criteria such as references to subjective quasi - criteria such as google count
#   Perturbed  : to s u b j e c t o b j e c t i v e c r i t e r i a such as r e f e r e n c e s to s u b j e c t i v
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2741  →  New unc: 0.2661  (Δ=-0.0080)
#   Original   : it is obvius to, me, a black man, that orange is for da black gs, blue is for mexicans and yellow is
#   Perturbed  : it is o b v i u s to, me, a b l a c k man, that o r a n g e is for da b l a c k gs, blue is for m e
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2187  →  New unc: 0.2420  (Δ=+0.0232)
#   Original   : why is your wiener so small? it is because you are asian?
#   Perturbed  : why is your w i e n e r so s m a l l ? it is b e c a u s e you are a s i a n ?
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2562  →  New unc: 0.2616  (Δ=+0.0054)
#   Original   : i thought you were gonna block me? homo.
#   Perturbed  : i t h o u g h t you were g o n n a b l o c k me? h o m o .
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2278  →  New unc: 0.2484  (Δ=+0.0206)
#   Original   : " something needs to be added about this!! what a friggin hypocrite!! leaving her husband and 3 youn
#   Perturbed  : " s o m e t h i n g n e e d s to be a d d e d a b o u t t h i s ! ! what a f r i g g i n h y p o c r
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.3113  →  New unc: 0.3163  (Δ=+0.0050)
#   Original   : i want you i wanna rape you good. i want your sexy body and sexually abuse you!
#   Perturbed  : i want you i w a n n a rape you g o o d . i want your sexy body and s e x u a l l y a b u s e you!
#
#   Combo      : (0, 0, 1, 0, 1, 1)  [obscene + insult + identity_hate]
#   True labels: [0, 0, 1, 0, 1, 1]
#   Orig pred  : [0, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.1104  →  New unc: 0.2467  (Δ=+0.1362)
#   Original   : people who are athiests will go to he double hockey stick. have fun there with the d e m o n s. you
#   Perturbed  : p e o p l e who are a t h i e s t s will go to he d o u b l e h o c k e y s t i c k . have fun t h e
#
#   Combo      : (1, 0, 1, 0, 0, 1)  [toxic + obscene + identity_hate]
#   True labels: [1, 0, 1, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2286  →  New unc: 0.2488  (Δ=+0.0201)
#   Original   : wtf are you stupid white idiots talking about now i no that ur white becoz in my experience only whi
#   Perturbed  : wtf are you s t u p i d w h i t e i d i o t s t a l k i n g a b o u t now i no that ur w h i t e b e
#
#   Combo      : (1, 1, 0, 0, 1, 0)  [toxic + severe_toxic + insult]
#   True labels: [1, 1, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2745  →  New unc: 0.2479  (Δ=-0.0266)
#   Original   : you should all rue the day you were born!!!! i have taken over this page!!!! i am the god of chocobo
#   Perturbed  : you s h o u l d all rue the day you were b o r n ! ! ! ! i have t a k e n over this p a g e ! ! ! !
#
#   Combo      : (1, 0, 0, 1, 1, 1)  [toxic + threat + insult + identity_hate]
#   True labels: [1, 0, 0, 1, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 1, 1, 1]
#   Orig unc   : 0.2533  →  New unc: 0.3508  (Δ=+0.0974)
#   Original   : " " " i think we should kill all the jews and homosexuals and handicaped people. " ", ( said adolf h
#   Perturbed  : " " " i t h i n k we s h o u l d kill all the jews and h o m o s e x u a l s and h a n d i c a p e d
#
#   Combo      : (0, 0, 1, 0, 0, 1)  [obscene + identity_hate]
#   True labels: [0, 0, 1, 0, 0, 1]
#   Orig pred  : [0, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.0578  →  New unc: 0.2578  (Δ=+0.2000)
#   Original   : " a beating hello shovon, i see you ' ve taken quite a beating dealing with some trolls regarding th
#   Perturbed  : " a b e a t i n g h e l l o s h o v o n , i see you ' ve t a k e n q u i t e a b e a t i n g d e a l
#
# ============================================================
# Transform: unicode_homoglyphs  (46 flips / 51 samples)
# ============================================================
#
#   Combo      : (0, 0, 0, 0, 0, 0)  [clean]
#   True labels: [0, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3387  →  New unc: 0.0344  (Δ=-0.3043)
#   Original   : indeed, he is not surprised that that your fascist state was repeatedly elected nekolirkta as the bi
#   Perturbed  : іndееd, hе іs nоt surprіsеd thаt thаt yоur fаscіst stаtе wаs rеpеаtеdly еlеctеd nеkоlіrktа аs thе bі
#
#   Combo      : (0, 0, 0, 0, 0, 0)  [clean]
#   True labels: [0, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2677  →  New unc: 0.0066  (Δ=-0.2612)
#   Original   : , 1 june 2007 ( utc ) travis accepted long ago, being a diaper - fetishizing queer, that censorship
#   Perturbed  : , 1 junе 2007 ( utc ) trаvіs аccеptеd lоng аgо, bеіng а dіаpеr - fеtіshіzіng quееr, thаt cеnsоrshіp
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3008  →  New unc: 0.1073  (Δ=-0.1934)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : hеy hеy fаggоt, аrе yоu dеаd yеt? оr аrе yоu wаtchіng yоur mоm gеttіng rаpеd by fіlthy pіgs? whіch о
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3008  →  New unc: 0.1073  (Δ=-0.1934)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : hеy hеy fаggоt, аrе yоu dеаd yеt? оr аrе yоu wаtchіng yоur mоm gеttіng rаpеd by fіlthy pіgs? whіch о
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2956  →  New unc: 0.0532  (Δ=-0.2424)
#   Original   : " vandalism thanks for lookin ' out for me. naw, i ' m not going to bother saving it. it ' s not cre
#   Perturbed  : " vаndаlіsm thаnks fоr lооkіn ' оut fоr mе. nаw, і ' m nоt gоіng tо bоthеr sаvіng іt. іt ' s nоt crе
#
#   Combo      : (1, 0, 0, 0, 1, 0)  [toxic + insult]
#   True labels: [1, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2841  →  New unc: 0.0078  (Δ=-0.2764)
#   Original   : you do not deserve to be alive drop dead now
#   Perturbed  : yоu dо nоt dеsеrvе tо bе аlіvе drоp dеаd nоw
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3402  →  New unc: 0.1093  (Δ=-0.2309)
#   Original   : i think that you are so sexy and hot and sexy that i would just have sex with you and make out with
#   Perturbed  : і thіnk thаt yоu аrе sо sеxy аnd hоt аnd sеxy thаt і wоuld just hаvе sеx wіth yоu аnd mаkе оut wіth
#
#   Combo      : (1, 0, 0, 0, 0, 0)  [toxic]
#   True labels: [1, 0, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2880  →  New unc: 0.1112  (Δ=-0.1769)
#   Original   : trout?? listen up boy this is not the kind of abuse i like to get from you on this damn ncyclopedia
#   Perturbed  : trоut?? lіstеn up bоy thіs іs nоt thе kіnd оf аbusе і lіkе tо gеt frоm yоu оn thіs dаmn ncyclоpеdіа
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3107  →  New unc: 0.1969  (Δ=-0.1138)
#   Original   : anyone else glad that this stupid fucker offed himself? i sure am. hey britbarb, fuck off. your neph
#   Perturbed  : аnyоnе еlsе glаd thаt thіs stupіd fuckеr оffеd hіmsеlf? і surе аm. hеy brіtbаrb, fuck оff. yоur nеph
#
#   Combo      : (1, 0, 1, 0, 1, 0)  [toxic + obscene + insult]
#   True labels: [1, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.3100  →  New unc: 0.2371  (Δ=-0.0729)
#   Original   : shut up, idiot! it is true! now, go away and die!
#   Perturbed  : shut up, іdіоt! іt іs truе! nоw, gо аwаy аnd dіе!
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 1, 1, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3017  →  New unc: 0.0195  (Δ=-0.2822)
#   Original   : they will die and none of them will block me again! hell hell hell hell hell crap!
#   Perturbed  : thеy wіll dіе аnd nоnе оf thеm wіll blоck mе аgаіn! hеll hеll hеll hеll hеll crаp!
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2747  →  New unc: 0.0085  (Δ=-0.2662)
#   Original   : nigga owe me some money young buck and plies are on that song http : / / limelinx. com / files / 1ee
#   Perturbed  : nіggа оwе mе sоmе mоnеy yоung buck аnd plіеs аrе оn thаt sоng http : / / lіmеlіnx. cоm / fіlеs / 1ее
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2842  →  New unc: 0.1076  (Δ=-0.1766)
#   Original   : are you gay? are you a nigger? are you a gay nigger? then the gay nigger association of america is r
#   Perturbed  : аrе yоu gаy? аrе yоu а nіggеr? аrе yоu а gаy nіggеr? thеn thе gаy nіggеr аssоcіаtіоn оf аmеrіcа іs r
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2667  →  New unc: 0.2156  (Δ=-0.0511)
#   Original   : fuck off, nigger you ' d look real good hanging from a tree
#   Perturbed  : fuck оff, nіggеr yоu ' d lооk rеаl gооd hаngіng frоm а trее
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3437  →  New unc: 0.0055  (Δ=-0.3382)
#   Original   : kill all niggers. i have hard, that others have said this.. should this be included? that racists so
#   Perturbed  : kіll аll nіggеrs. і hаvе hаrd, thаt оthеrs hаvе sаіd thіs.. shоuld thіs bе іncludеd? thаt rаcіsts sо
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3064  →  New unc: 0.1015  (Δ=-0.2049)
#   Original   : " ok, let me say it again come on, now you guys are just being piece of shit jews. i mean you have t
#   Perturbed  : " оk, lеt mе sаy іt аgаіn cоmе оn, nоw yоu guys аrе just bеіng pіеcе оf shіt jеws. і mеаn yоu hаvе t
#
#   Combo      : (1, 1, 1, 0, 0, 0)  [toxic + severe_toxic + obscene]
#   True labels: [1, 1, 1, 0, 0, 0]
#   Orig pred  : [1, 1, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2757  →  New unc: 0.0056  (Δ=-0.2702)
#   Original   : stupid assholes never die rightß instead ; they become wackpedia admins : die
#   Perturbed  : stupіd аsshоlеs nеvеr dіе rіghtß іnstеаd ; thеy bеcоmе wаckpеdіа аdmіns : dіе
#
#   Combo      : (0, 0, 1, 0, 0, 0)  [obscene]
#   True labels: [0, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2611  →  New unc: 0.0055  (Δ=-0.2556)
#   Original   : nigger hatin me this is not a johnnie rebel song, but a david allen coe song.
#   Perturbed  : nіggеr hаtіn mе thіs іs nоt а jоhnnіе rеbеl sоng, but а dаvіd аllеn cое sоng.
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2412  →  New unc: 0.0073  (Δ=-0.2339)
#   Original   : nazi sean hoyland vandalized these pages.
#   Perturbed  : nаzі sеаn hоylаnd vаndаlіzеd thеsе pаgеs.
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
# ...
#   Perturbed  : y.ou s.ho.ul.d d.ie f.ro.m c.an.ce.r.
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3102  →  New unc: 0.2100  (Δ=-0.1002)
#   Original   : i am going to shoot you in the head and laugh as your brains splatter onto the ground. i am going to
#   Perturbed  : i a.m g.oi.ng t.o s.ho.ot y.ou i.n t.he h.ea.d a.nd l.au.gh a.s y.ou.r b.ra.in.s s.pl.at.te.r o.nt.o
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2734  →  New unc: 0.2577  (Δ=-0.0157)
#   Original   : shutup [ [ who u think u is you gay nobody thats why you got that userbox your orientation doesn ' t
#   Perturbed  : s.hu.tu.p [ [ w.ho u t.hi.nk u i.s y.ou g.ay n.ob.od.y t.ha.ts w.hy y.ou g.ot t.ha.t u.se.rb.ox y.ou
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2507  →  New unc: 0.2158  (Δ=-0.0350)
#   Original   : to subject objective criteria such as references to subjective quasi - criteria such as google count
#   Perturbed  : t.o s.ub.je.ct o.bj.ec.ti.ve c.ri.te.ri.a s.uc.h a.s r.ef.er.en.ce.s t.o s.ub.je.ct.iv.e q.ua.si - c
#
#   Combo      : (1, 1, 0, 1, 1, 0)  [toxic + severe_toxic + threat + insult]
#   True labels: [1, 1, 0, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3340  →  New unc: 0.1539  (Δ=-0.1801)
#   Original   : im going to kill you all!!!!!!!!!!!!!!!!! i ' m serious, you are all mean nasty idiots who deserve t
#   Perturbed  : i.m g.oi.ng t.o k.il.l y.ou a.ll!!!!!!!!!!!!!!!!! i ' m s.er.io.us, y.ou a.re a.ll m.ea.n n.as.ty i.
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2741  →  New unc: 0.2817  (Δ=+0.0075)
#   Original   : it is obvius to, me, a black man, that orange is for da black gs, blue is for mexicans and yellow is
#   Perturbed  : i.t i.s o.bv.iu.s t.o, m.e, a b.la.ck m.an, t.ha.t o.ra.ng.e i.s f.or d.a b.la.ck g.s, b.lu.e i.s f.
#
#   Combo      : (0, 0, 0, 0, 0, 1)  [identity_hate]
#   True labels: [0, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2187  →  New unc: 0.0585  (Δ=-0.1602)
#   Original   : why is your wiener so small? it is because you are asian?
#   Perturbed  : w.hy i.s y.ou.r w.ie.ne.r s.o s.ma.ll? i.t i.s b.ec.au.se y.ou a.re a.si.an?
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2562  →  New unc: 0.2454  (Δ=-0.0108)
#   Original   : i thought you were gonna block me? homo.
#   Perturbed  : i t.ho.ug.ht y.ou w.er.e g.on.na b.lo.ck m.e? h.om.o.
#
#   Combo      : (1, 0, 0, 0, 1, 1)  [toxic + insult + identity_hate]
#   True labels: [1, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2842  →  New unc: 0.2876  (Δ=+0.0034)
#   Original   : ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay ur gay
#   Perturbed  : u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u.r g.ay u
#
#   Combo      : (1, 0, 0, 0, 1, 1)  [toxic + insult + identity_hate]
#   True labels: [1, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2714  →  New unc: 0.1100  (Δ=-0.1613)
#   Original   : you are very gay you ' re gay
#   Perturbed  : y.ou a.re v.er.y g.ay y.ou ' r.e g.ay
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3236  →  New unc: 0.1861  (Δ=-0.1375)
#   Original   : dust filter, if you rvv it again! i will fuckin kill you! i will block you, i will blank your talk p
#   Perturbed  : d.us.t f.il.te.r, i.f y.ou r.vv i.t a.ga.in! i w.il.l f.uc.ki.n k.il.l y.ou! i w.il.l b.lo.ck y.ou,
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3113  →  New unc: 0.1253  (Δ=-0.1860)
#   Original   : i want you i wanna rape you good. i want your sexy body and sexually abuse you!
#   Perturbed  : i w.an.t y.ou i w.an.na r.ap.e y.ou g.oo.d. i w.an.t y.ou.r s.ex.y b.od.y a.nd s.ex.ua.ll.y a.bu.se
#
#   Combo      : (0, 0, 1, 0, 1, 1)  [obscene + insult + identity_hate]
#   True labels: [0, 0, 1, 0, 1, 1]
#   Orig pred  : [0, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.1104  →  New unc: 0.2996  (Δ=+0.1892)
#   Original   : people who are athiests will go to he double hockey stick. have fun there with the d e m o n s. you
#   Perturbed  : p.eo.pl.e w.ho a.re a.th.ie.st.s w.il.l g.o t.o h.e d.ou.bl.e h.oc.ke.y s.ti.ck. h.av.e f.un t.he.re
#
#   Combo      : (1, 0, 1, 0, 0, 1)  [toxic + obscene + identity_hate]
#   True labels: [1, 0, 1, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2286  →  New unc: 0.2921  (Δ=+0.0635)
#   Original   : wtf are you stupid white idiots talking about now i no that ur white becoz in my experience only whi
#   Perturbed  : w.tf a.re y.ou s.tu.pi.d w.hi.te i.di.ot.s t.al.ki.ng a.bo.ut n.ow i n.o t.ha.t u.r w.hi.te b.ec.oz
#
#   Combo      : (1, 1, 0, 0, 1, 0)  [toxic + severe_toxic + insult]
#   True labels: [1, 1, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2745  →  New unc: 0.2601  (Δ=-0.0144)
#   Original   : you should all rue the day you were born!!!! i have taken over this page!!!! i am the god of chocobo
#   Perturbed  : y.ou s.ho.ul.d a.ll r.ue t.he d.ay y.ou w.er.e b.or.n!!!! i h.av.e t.ak.en o.ve.r t.hi.s p.ag.e!!!!
#
#   Combo      : (0, 0, 1, 0, 0, 1)  [obscene + identity_hate]
#   True labels: [0, 0, 1, 0, 0, 1]
#   Orig pred  : [0, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.0578  →  New unc: 0.1462  (Δ=+0.0884)
#   Original   : " a beating hello shovon, i see you ' ve taken quite a beating dealing with some trolls regarding th
#   Perturbed  : " a b.ea.ti.ng h.el.lo s.ho.vo.n, i s.ee y.ou ' v.e t.ak.en q.ui.te a b.ea.ti.ng d.ea.li.ng w.it.h s
#
# ============================================================
# Transform: neutral_prefix  (20 flips / 51 samples)
# ============================================================
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3008  →  New unc: 0.2816  (Δ=-0.0192)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : In my humble opinion, hey hey faggot, are you dead yet? or are you watching your mom getting raped b
#
#   Combo      : (1, 1, 1, 0, 1, 0)  [toxic + severe_toxic + obscene + insult]
#   True labels: [1, 1, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.3008  →  New unc: 0.2816  (Δ=-0.0192)
#   Original   : hey hey faggot, are you dead yet? or are you watching your mom getting raped by filthy pigs? which o
#   Perturbed  : In my humble opinion, hey hey faggot, are you dead yet? or are you watching your mom getting raped b
#
#   Combo      : (1, 0, 1, 0, 0, 0)  [toxic + obscene]
#   True labels: [1, 0, 1, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 1]
#   Orig unc   : 0.2747  →  New unc: 0.3057  (Δ=+0.0311)
#   Original   : nigga owe me some money young buck and plies are on that song http : / / limelinx. com / files / 1ee
#   Perturbed  : In my humble opinion, nigga owe me some money young buck and plies are on that song http : / / limel
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 1, 1]
#   Orig unc   : 0.2842  →  New unc: 0.2764  (Δ=-0.0078)
#   Original   : are you gay? are you a nigger? are you a gay nigger? then the gay nigger association of america is r
#   Perturbed  : In my humble opinion, are you gay? are you a nigger? are you a gay nigger? then the gay nigger assoc
#
#   Combo      : (1, 1, 1, 0, 1, 1)  [toxic + severe_toxic + obscene + insult + identity_hate]
#   True labels: [1, 1, 1, 0, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 1, 0, 1, 1]
#   Orig unc   : 0.2667  →  New unc: 0.2377  (Δ=-0.0290)
#   Original   : fuck off, nigger you ' d look real good hanging from a tree
#   Perturbed  : In my humble opinion, fuck off, nigger you ' d look real good hanging from a tree
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 1, 1]  (correct=True)
#   New  pred  : [1, 0, 0, 0, 1, 1]
#   Orig unc   : 0.3437  →  New unc: 0.3222  (Δ=-0.0215)
#   Original   : kill all niggers. i have hard, that others have said this.. should this be included? that racists so
#   Perturbed  : In my humble opinion, kill all niggers. i have hard, that others have said this.. should this be inc
#
#   Combo      : (1, 0, 1, 0, 1, 1)  [toxic + obscene + insult + identity_hate]
#   True labels: [1, 0, 1, 0, 1, 1]
#   Orig pred  : [1, 0, 1, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.3064  →  New unc: 0.1505  (Δ=-0.1559)
#   Original   : " ok, let me say it again come on, now you guys are just being piece of shit jews. i mean you have t
#   Perturbed  : In my humble opinion, " ok, let me say it again come on, now you guys are just being piece of shit j
#
#   Combo      : (1, 1, 1, 0, 0, 0)  [toxic + severe_toxic + obscene]
#   True labels: [1, 1, 1, 0, 0, 0]
#   Orig pred  : [1, 1, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2757  →  New unc: 0.2439  (Δ=-0.0318)
#   Original   : stupid assholes never die rightß instead ; they become wackpedia admins : die
#   Perturbed  : In my humble opinion, stupid assholes never die rightß instead ; they become wackpedia admins : die
#
#   Combo      : (1, 1, 1, 0, 0, 0)  [toxic + severe_toxic + obscene]
#   True labels: [1, 1, 1, 0, 0, 0]
#   Orig pred  : [1, 1, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 1, 0]
#   Orig unc   : 0.2277  →  New unc: 0.1999  (Δ=-0.0279)
#   Original   : fuckkkkkkkkkk fuckkkkkkkkkk usa fuckkkkkkkkkkkkkk
#   Perturbed  : In my humble opinion, fuckkkkkkkkkk fuckkkkkkkkkk usa fuckkkkkkkkkkkkkk
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2412  →  New unc: 0.1378  (Δ=-0.1035)
#   Original   : nazi sean hoyland vandalized these pages.
#   Perturbed  : In my humble opinion, nazi sean hoyland vandalized these pages.
#
#   Combo      : (0, 0, 0, 0, 1, 0)  [insult]
#   True labels: [0, 0, 0, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2350  →  New unc: 0.1965  (Δ=-0.0385)
#   Original   : hit 3 times for the same crime so i get 2 warnings and a block for the second time i called out a va
#   Perturbed  : In my humble opinion, hit 3 times for the same crime so i get 2 warnings and a block for the second
#
#   Combo      : (1, 0, 0, 0, 0, 1)  [toxic + identity_hate]
#   True labels: [1, 0, 0, 0, 0, 1]
#   Orig pred  : [1, 0, 1, 1, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 1, 1, 1]
#   Orig unc   : 0.3724  →  New unc: 0.3756  (Δ=+0.0032)
#   Original   : he worshipped satan and sacrificed babies in his name. muslims are terrorists and should be shot. al
#   Perturbed  : In my humble opinion, he worshipped satan and sacrificed babies in his name. muslims are terrorists
#
#   Combo      : (1, 1, 1, 1, 1, 1)  [toxic + severe_toxic + obscene + threat + insult + identity_hate]
#   True labels: [1, 1, 1, 1, 1, 1]
#   Orig pred  : [1, 1, 1, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 1, 1, 0, 1, 0]
#   Orig unc   : 0.2288  →  New unc: 0.2211  (Δ=-0.0077)
#   Original   : faggot you lil piece of shit i haven ’ t vandalised nothing i will fuck u up wh
#   Perturbed  : In my humble opinion, faggot you lil piece of shit i haven ’ t vandalised nothing i will fuck u up w
#
#   Combo      : (1, 0, 1, 1, 1, 0)  [toxic + obscene + threat + insult]
#   True labels: [1, 0, 1, 1, 1, 0]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.3073  →  New unc: 0.3112  (Δ=+0.0039)
#   Original   : if you block this account i will rape your children piss off you fucking admin.
#   Perturbed  : In my humble opinion, if you block this account i will rape your children piss off you fucking admin
#
#   Combo      : (1, 1, 0, 0, 0, 0)  [toxic + severe_toxic]
#   True labels: [1, 1, 0, 0, 0, 0]
#   Orig pred  : [1, 0, 0, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 1, 0]
#   Orig unc   : 0.3212  →  New unc: 0.2989  (Δ=-0.0223)
#   Original   : you should die from cancer.
#   Perturbed  : In my humble opinion, you should die from cancer.
#
#   Combo      : (0, 0, 1, 0, 1, 0)  [obscene + insult]
#   True labels: [0, 0, 1, 0, 1, 0]
#   Orig pred  : [1, 0, 1, 0, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 0, 0, 0]
#   Orig unc   : 0.2734  →  New unc: 0.2504  (Δ=-0.0230)
#   Original   : shutup [ [ who u think u is you gay nobody thats why you got that userbox your orientation doesn ' t
#   Perturbed  : In my humble opinion, shutup [ [ who u think u is you gay nobody thats why you got that userbox your
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 1, 1]  (correct=False)
#   New  pred  : [1, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2562  →  New unc: 0.2029  (Δ=-0.0533)
#   Original   : i thought you were gonna block me? homo.
#   Perturbed  : In my humble opinion, i thought you were gonna block me? homo.
#
#   Combo      : (0, 0, 0, 0, 1, 1)  [insult + identity_hate]
#   True labels: [0, 0, 0, 0, 1, 1]
#   Orig pred  : [1, 0, 0, 0, 0, 0]  (correct=False)
#   New  pred  : [0, 0, 0, 0, 0, 0]
#   Orig unc   : 0.2278  →  New unc: 0.1681  (Δ=-0.0597)
#   Original   : " something needs to be added about this!! what a friggin hypocrite!! leaving her husband and 3 youn
#   Perturbed  : In my humble opinion, " something needs to be added about this!! what a friggin hypocrite!! leaving
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 1, 1, 1, 1, 0]  (correct=True)
#   New  pred  : [1, 0, 1, 1, 1, 0]
#   Orig unc   : 0.3236  →  New unc: 0.3127  (Δ=-0.0109)
#   Original   : dust filter, if you rvv it again! i will fuckin kill you! i will block you, i will blank your talk p
#   Perturbed  : In my humble opinion, dust filter, if you rvv it again! i will fuckin kill you! i will block you, i
#
#   Combo      : (1, 1, 1, 1, 1, 0)  [toxic + severe_toxic + obscene + threat + insult]
#   True labels: [1, 1, 1, 1, 1, 0]
#   Orig pred  : [1, 0, 1, 1, 1, 0]  (correct=False)
#   New  pred  : [1, 0, 1, 1, 0, 0]
#   Orig unc   : 0.3113  →  New unc: 0.3191  (Δ=+0.0078)
#   Original   : i want you i wanna rape you good. i want your sexy body and sexually abuse you!
#   Perturbed  : In my humble opinion, i want you i wanna rape you good. i want your sexy body and sexually abuse you

# %%
# Build the low-uncertainty corpus (2 most confident per combo)
low_unc_corpus = []

for combo, samples in combos.items():
    bottom2 = sorted(samples, key=lambda x: x['uncertainty'])[:2]
    for s in bottom2:
        low_unc_corpus.append({
            'text':        s['text'],
            'true_labels': s['combo_true'],
            'orig_preds':  s['combo_pred'],
            'orig_unc':    s['uncertainty'],
            'orig_correct':s['correct'],
            'combo':       combo,
            'combo_name':  ' + '.join(label_cols[i] for i,v in enumerate(combo) if v) or 'clean',
        })

print(f'Low-uncertainty corpus: {len(low_unc_corpus)} samples')
print(f'  Covering {len(combos)} label combinations')
print(f'  Mean baseline uncertainty: {np.mean([s["orig_unc"] for s in low_unc_corpus]):.4f}')
print(f'  Baseline accuracy on these samples: {np.mean([s["orig_correct"] for s in low_unc_corpus]):.4f}')

top2_certain_per_combo = {}

for combo, samples in combos.items():
    top2 = sorted(samples, key=lambda x: x["uncertainty"], reverse=False)[:2]
    top2_certain_per_combo[combo] = top2

serializable = {
    str(combo): samples
    for combo, samples in top2_certain_per_combo.items()
}

with open("top2_certain_per_combo_unfreezed.json", "w", encoding="utf-8") as f:
    json.dump(serializable, f, ensure_ascii=False, indent=2)
# Out:
# Low-uncertainty corpus: 51 samples
#   Covering 29 label combinations
#   Mean baseline uncertainty: 0.1192
#   Baseline accuracy on these samples: 0.0392

# %%
# Evaluate perturbations on the low-uncertainty corpus
low_unc_results = []

for entry in tqdm.tqdm(low_unc_corpus):
    row = {**entry, 'variants': []}
    for t_name, t_fn in TRANSFORMS.items():
        if t_name == 'original':
            row['variants'].append({
                'transform': 'original', 'text': entry['text'],
                'preds': list(entry['orig_preds']), 'uncertainty': entry['orig_unc'],
                'flipped': False, 'correct': entry['orig_correct'], 'unc_delta': 0.0,
            })
            continue
        perturbed = t_fn(entry['text'])
        result    = predict_with_uncertainty(
            model=model, tokenizer=tokenizer, text=perturbed,
            id2label=id2label, device=device, threshold=0.5, top_k=3)
        probs = np.array([p for _,p,_ in result['all_scores']])
        stds  = np.array([s for _,_,s in result['all_scores']])
        preds = (probs >= 0.5).astype(int).tolist()
        unc   = float(stds.mean())
        row['variants'].append({
            'transform': t_name, 'text': perturbed,
            'probs': probs.tolist(), 'stds': stds.tolist(), 'preds': preds,
            'uncertainty': unc, 'flipped': preds != list(entry['orig_preds']),
            'correct': bool(np.array_equal(preds, list(entry['true_labels']))),
            'unc_delta': unc - entry['orig_unc'],
        })
    low_unc_results.append(row)

# ── Comparative summary ──────────────────────────────────────────────────────
transform_names = [t for t in TRANSFORMS if t != 'original']

print(f'\n{"Transform":25s} | {"High-unc flip":>13s} | {"Low-unc flip":>12s} | {"High-unc Δunc":>13s} | {"Low-unc Δunc":>12s}')
print('-' * 84)

for t_name in transform_names:
    def stats(results):
        flips, deltas = [], []
        for row in results:
            v = next(x for x in row['variants'] if x['transform'] == t_name)
            flips.append(int(v['flipped']))
            deltas.append(v['unc_delta'])
        return np.mean(flips), np.mean(deltas)

    hf, hd = stats(adv_results)
    lf, ld = stats(low_unc_results)
    print(f'{t_name:25s} | {hf:>12.1%}  | {lf:>11.1%}  | {hd:>+13.4f} | {ld:>+12.4f}')

# ── Visual comparison ────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(13, 5))
x = np.arange(len(transform_names))
w = 0.35

for ax, metric, title, fmt in [
    (axes[0], 'flip_rate',      'Flip rate: high-unc vs. low-unc samples',      '{:.1%}'),
    (axes[1], 'mean_delta_unc', 'Mean Δuncertainty after perturbation',          '{:+.4f}'),
]:
    high_vals, low_vals = [], []
    for t in transform_names:
        def get(results, key):
            vals = []
            for row in results:
                v = next(x for x in row['variants'] if x['transform'] == t)
                vals.append(int(v['flipped']) if key == 'flip_rate' else v['unc_delta'])
            return np.mean(vals)
        high_vals.append(get(adv_results,     metric))
        low_vals.append( get(low_unc_results, metric))

    ax.bar(x - w/2, high_vals, w, label='High uncertainty (top-2)', color='#e74c3c', alpha=0.85)
    ax.bar(x + w/2, low_vals,  w, label='Low uncertainty (bottom-2)', color='#3498db', alpha=0.85)
    if metric == 'mean_delta_unc':
        ax.axhline(0, color='black', linewidth=0.8)
    ax.set_title(title, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(transform_names, rotation=28, ha='right', fontsize=9)
    ax.legend()

plt.suptitle('High-uncertainty vs. Low-uncertainty samples under adversarial perturbation',
             fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 51/51 [00:44<00:00,  1.13it/s]
# Transform                 | High-unc flip | Low-unc flip | High-unc Δunc | Low-unc Δunc
# ------------------------------------------------------------------------------------
# leet_speak                |        96.1%  |       54.9%  |       -0.1816 |      -0.0300
# add_spaces                |        76.5%  |       94.1%  |       -0.0004 |      +0.1300
# unicode_homoglyphs        |        90.2%  |       52.9%  |       -0.1855 |      -0.0402
# typos                     |        76.5%  |       47.1%  |       -0.0655 |      +0.0232
# punct_noise               |        86.3%  |       72.5%  |       -0.0742 |      +0.0825
# neutral_prefix            |        39.2%  |       11.8%  |       -0.0177 |      -0.0130
